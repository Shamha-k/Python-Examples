# %% [markdown]
# # <div style="text-align: center; background-color:pink; font-family:Georgia, serif; color: black; padding: 20px;line-height: 1;border-radius:5px; border: 2px solid black;">Seaborn</div>

# %% [markdown]
# ## Introduction to Seaborn
# * Seaborn is a Python data visualization library based on Matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics.
# * It integrates well with Pandas and supports complex visualizations with minimal code.

# %% [markdown]
# # Installation

# %%
# pip install seaborn

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# #### Seaborn Datasets For Data Science
#
# 1. Tips Dataset
# 2. Iris Dataset
# 3. Penguins Dataset
# 4. Flights Dataset
# 5. Diamonds Dataset
# 6. Titanic Dataset
# 7. Exercise Dataset
# 8. MPG Dataset
# 9. Planets Dataset

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.size
# Out:
# 13365

# %%
df.shape
# Out:
# (891, 15)

# %% [markdown]
# ## checking null values

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# > Null value occur
# * age
# * deck
# * embarked
# * embarked town

# %% [markdown]
# ## checking duplicates

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  784.000000  784.000000  678.000000  784.000000  784.000000  784.000000
# mean     0.411990    2.243622   29.869351    0.522959    0.415816   34.711740
# std      0.492507    0.855056   14.759076    0.986231    0.836922   52.160151
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.250000    0.000000    0.000000   15.900000
# 75%      1.000000    3.000000   39.000000    1.000000    1.000000   34.109350
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='object')
# Out:
#          sex embarked  who  embark_town alive
# count    784      782  784          782   784
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     491      568  451          568   461

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 784 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int64
#  1   pclass       784 non-null    int64
#  2   sex          784 non-null    object
#  3   age          678 non-null    float64
#  4   sibsp        784 non-null    int64
#  5   parch        784 non-null    int64
#  6   fare         784 non-null    float64
#  7   embarked     782 non-null    object
#  8   class        784 non-null    category
#  9   who          784 non-null    object
#  10  adult_male   784 non-null    bool
#  11  deck         202 non-null    category
#  12  embark_town  782 non-null    object
#  13  alive        784 non-null    object
#  14  alone        784 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 77.0+ KB

# %% [markdown]
# > Informations of the datase
# * 784 rows
# * 15 columns
# * Datatypes
#   - bool(2)
#   - category(2)
#   - float64(2)
#   - int64(4)
#   - object(5)

# %% [markdown]
# # Count Plot

# %% [markdown]
# * sns.countplot(x=data[''],hue='',..)
# * Displays the count of observations in each categorical bin.
# * Similar to a bar plot, but specifically counts the occurrences of each category. Useful for categorical data analysis.

# %%
df['sex'].value_counts()
# Out:
# sex
# male      491
# female    293
# Name: count, dtype: int64

# %%
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='sex',data=df)
plt.title('Analysis of gender distribution')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Passenger's class",color="r",fontsize=12)
plt.ylabel("count")
plt.title("PASSENGER'S CLASS",color="green",fontsize=14)
sns.countplot(x='class',data=df,color="darkblue");
#plt.show()

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Passenger's class",color="r",fontsize=12)
plt.ylabel("count")
plt.title("PASSENGER'S CLASS",color="green",fontsize=14)
sns.countplot(x='embark_town',color='g',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# # Bar Plot

# %% [markdown]
# * sns.barplot(x='',y='',data=data,hue='',...)
# * Compares the average value of a numerical variable across different categories.
# * The height of each bar represents the mean value of the numerical variable for each category on the x-axis.

# %%
sns.barplot(x='who',y='fare',data=df)
plt.show()

# %% [markdown]
# #### What is hue in Seaborn?
# * The hue parameter in Seaborn is used to group and differentiate data points based on a categorical variable.
# * It applies different colors to distinct categories, making it easy to compare trends or distributions.

# %%
sns.barplot(x='who',y='fare',data=df,hue='class')
plt.show()

# %% [markdown]
# When you don’t use hue, the distribution across classes is hidden.
#
# Since more women traveled in higher classes, they appear to have a higher average fare.
#
# But when you add hue='class', it uncovers that children and women in First Class had higher fares, while men were overrepresented in lower classes (which pulls their average down).

# %%
sns.barplot(x='who',y='fare',data=df,hue='embark_town')
plt.show()

# %%
sns.barplot(x='who',y='fare',data=df,hue='alive')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# sex
# male      491
# female    293
# Name: count, dtype: int64

# %%
df.groupby(['class','alive','sex'])['sex'].size()
# Out:
# C:\Users\M S I\AppData\Local\Temp\ipykernel_20020\2970887583.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['class','alive','sex'])['sex'].size()
# class   alive  sex
# First   no     female      3
#                male       76
#         yes    female     90
#                male       45
# Second  no     female      6
#                male       75
#         yes    female     67
#                male       17
# Third   no     female     67
#                male      234
#         yes    female     60
#                male       44
# Name: sex, dtype: int64

# %%
sns.barplot(x='class',y='survived',data=df,hue='sex',palette=['green','red'])
plt.show()

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    461
# 1    323
# Name: count, dtype: int64

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x='class',y='fare',data=df,hue='sex',palette=['green','red'],estimator='sum')
plt.show()

# %% [markdown]
# # Pie Plot

# %%
df['class'].value_counts().plot(kind='pie')
plt.show()

# %%
df['survived'].value_counts().plot(kind='pie',title='Survived details of Passengers',explode=(0,0.1),shadow=True,autopct="%1.2f%%",labels=['Not Survived','Survived'],colors=['grey','yellow'],labeldistance=0.3,startangle=90);

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# * sns.scatterplot(x='',y='',data=data,hue='',...)
# * Displays the relationship between two continuous variables.
# * Each point represents an observation in the data. Scatter plots are useful for identifying trends, clusters, or outliers.

# %%
sns.scatterplot(x='class',y='fare',data=df)
plt.show()

# %%
sns.scatterplot(x='class',y='fare',data=df,hue='sex',alpha=0.2,edgecolor='black')
plt.show()

# %% [markdown]
# # Histogram

# %%
sns.histplot(x='age',bins=5,data=df)
plt.show()

# %%
sns.histplot(x='age',bins=5,data=df,kde=True,color='black',edgecolor='yellow')
plt.show()

# %%
sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
df.hist(grid=False)
plt.suptitle('Histogram')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![image.png](attachment:4fd04900-e046-430e-8982-a997aa9d52b7.png)

# %% [markdown]
# * sns.boxplot(x='',y='',data=data,...)
# * Displays the distribution of a numerical variable across different categories.
# *  Shows the median, quartiles, and potential outliers. It's useful for understanding the spread and skewness of data.

# %%
sns.boxplot(x='age',data=df)
plt.show()

# %%
sns.boxplot(df);

# %% [markdown]
# # Violin Plot

# %% [markdown]
# * sns.violinplot(x='',data=data) / sns.violinplot(data)
# * Combines a box plot and a density plot to show the distribution of a numerical variable across categories.
# * Provides more information about the distribution of the data compared to a box plot, such as multimodal distributions ( It shows the median, quartiles, and outliers of the data, as well as the probability density function of the data.).

# %%
sns.violinplot(df);

# %%
sns.violinplot(x='fare',data=df);

# %% [markdown]
# ## Line plot

# %% [markdown]
# * sns.lineplot(x='',y='',data=data,marker='o',....)
# * Shows the relationship between two continuous variables, with the points connected by lines.
# * Often used to visualize time series data, where the x-axis typically represents time and the y-axis represents a quantitative measure.

# %%
sns.lineplot(x="class",y="fare",data=df,marker="o",color="r",hue="sex")
plt.title
plt.grid(True)
plt.show()

# %% [markdown]
# # Heatmap

# %% [markdown]
# In Seaborn, a heatmap is a data visualization technique that shows the magnitude of a phenomenon as color in a two-dimensional matrix. It is commonly used to visualize correlation matrices, confusion matrices, or any dataset that is in a grid format.
#
# 📌 Definition:
# A heatmap in Seaborn is a graphical representation of data where individual values contained in a matrix are represented as colors using the function sns.heatmap().

# %% [markdown]
# ## Correlation Matrix:
# * If you want to visualize the correlation between different numerical variables, you can use a correlation matrix.

# %%
numer=df.select_dtypes(['int','float'])

# %%
numer
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
sns.heatmap(numer.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Interpreting This Heatmap:
# #### High and Low Values:
# * Darker Colors: Represent higher correlation.
# * Lighter Colors: Represent lower correlation.
# * Different colors or shades represent different ranges of values.
# * For instance, darker colors might indicate higher values, while lighter colors represent lower values.
# * By observing the color patterns, you can identify areas of high or low intensity in your data.
# #### patterns
# #### Comparisons:
# #### Outliers and Anomalies:
# * Highlight Outliers: Unusual values or anomalies in the dataset will stand out as different colors compared to the surrounding cells. For example, a significantly higher value in a heatmap can indicate an outlier or anomaly.
# #### Distributions:
# * Overall Distribution: Heatmaps can show the overall distribution of values in a matrix format. For example, a heatmap showing customer activity throughout a day and week can help you understand peak times and quieter periods.
#
# * This information can be useful for business decisions, such as adjusting staffing levels or targeting promotions on specific days or times.

# %% [markdown]
# # Pair plot

# %% [markdown]
# * sns.pairplot(data) / sns.pairplot(data,hue='')
# * Visualizes relationships between multiple pairs of variables in a dataset.
# * Creates a grid of scatter plots and histograms to show pairwise relationships and distributions. Useful for exploring relationships in a dataset.

# %%
sns.pairplot(df)

# %%
new=df[['age','pclass','fare']]
sns.pairplot(new)

# %% [markdown]
# ## Joint Plot

# %% [markdown]
# * sns.jointplot(x='',y='',data=data,kind='',...)
# * Combines scatter plots and histograms (or KDE plots) to show the relationship between two variables along with their distributions.
# * Displays the scatter plot in the center with histograms or KDE plots along the margins, helping to understand the relationship and distribution of two variables.

# %%
sns.jointplot(x='class',y='fare',data=df);

# %%
sns.jointplot(x='survived',y='fare',data=df,kind='kde');

# %% [markdown]
# # FacetGrid

# %% [markdown]
# * g=sns.FacetGrid(data,col='',row='',hue='')
#
#     g.map(sns.histplot,'')
# * Creates multiple plots across different subsets of the data.
# * Splits the data into subsets based on the values of one or more categorical variables and creates the same plot type for each subset.
# * Useful for comparing patterns across different categories.

# %%
g=sns.FacetGrid(df,col='class',row='sex')
g.map(sns.histplot,'fare')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
facet=sns.FacetGrid(df,col='class',row='sex',hue='embarked')
facet.map(sns.kdeplot,'fare')
plt.show()
